# %% [markdown]
# ## Part 1: Create Your Own Dataset (Foundation)

# %%
import pandas as pd

# %%
students = pd.DataFrame({
    "Name":["Abrihet Afwerki","Abebe Tesfaye","Almaz Bekele","Biniam Yohannes","Genet Tadesse","Dawit Getachew","Kidist Hailu","Ermias Assefa","Lielit Girma","Hagos Mekonnen","Samrawit Berhane","Yonas Desta","Tsehay Kebede","Arsema Hailemariam","Amanuel Tekle"],
    "ID":["UGR/23672/17","UGR/23672/17","UGR/23672/17","UGR/23672/17","UGR/23672/17","UGR/23672/17","UGR/23672/17","UGR/23672/17","UGR/23672/17","UGR/23672/17","UGR/23672/17","UGR/23672/17","UGR/23672/17","UGR/23672/17","UGR/23672/17"],
    "Age":[21,19,20,20,20,21,22,23,21,23,22,20,19,18,20],
    "Department": ["CSE","SE","ECE","EPCE","CSE","SE","ECE","EPCE","CSE","SE","ECE","EPCE","ECE","SE","EPCE"],
    "Gender": ["Female","Male","Female","Male","Female","Male","Female","Male","Female","Male","Female","Male","Female","Female","Male"],
    
},
index = [101,102,103,104,105,106,107,108,109,110,111,112,113,114,115])

# %%
students
# Out:
#                    Name            ID  Age Department  Gender
# 101     Abrihet Afwerki  UGR/23672/17   21        CSE  Female
# 102       Abebe Tesfaye  UGR/23672/17   19         SE    Male
# 103        Almaz Bekele  UGR/23672/17   20        ECE  Female
# 104     Biniam Yohannes  UGR/23672/17   20       EPCE    Male
# 105       Genet Tadesse  UGR/23672/17   20        CSE  Female
# 106      Dawit Getachew  UGR/23672/17   21         SE    Male
# 107        Kidist Hailu  UGR/23672/17   22        ECE  Female
# 108       Ermias Assefa  UGR/23672/17   23       EPCE    Male
# 109        Lielit Girma  UGR/23672/17   21        CSE  Female
# 110      Hagos Mekonnen  UGR/23672/17   23         SE    Male
# 111    Samrawit Berhane  UGR/23672/17   22        ECE  Female
# 112         Yonas Desta  UGR/23672/17   20       EPCE    Male
# 113       Tsehay Kebede  UGR/23672/17   19        ECE  Female
# 114  Arsema Hailemariam  UGR/23672/17   18         SE  Female
# ...
